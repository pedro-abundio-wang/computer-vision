# %% [markdown]
# # Checkpointing Models

# %%
import matplotlib.pyplot as plt

# This is a bit of magic to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import the necessary packages
from keras.callbacks import BaseLogger
import matplotlib.pyplot as plt
import numpy as np
import json
import os

# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.callbacks import LearningRateScheduler
from keras import backend as K

from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np

# %%
class MiniVGGNet:
    
    @staticmethod
    def build(width, height, depth, classes, batch_norm=True):
        # initialize the model along with the input shape to be
        # "channels last" and the channels dimension itself
        model = Sequential()
        inputShape = (height, width, depth)
        chanDim = -1

        # if we are using "channels first", update the input shape
        # and channels dimension
        if K.image_data_format() == "channels_first":
            inputShape = (depth, height, width)
            chanDim = 1

        # first CONV => RELU => CONV => RELU => POOL layer set
        model.add(Conv2D(32, (3, 3), padding="same",
        input_shape=inputShape))
        model.add(Activation("relu"))
        if batch_norm:
            model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(32, (3, 3), padding="same"))
        model.add(Activation("relu"))
        if batch_norm:
            model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # second CONV => RELU => CONV => RELU => POOL layer set
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        if batch_norm:
            model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        if batch_norm:
            model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # first (and only) set of FC => RELU layers
        model.add(Flatten())
        model.add(Dense(512))
        model.add(Activation("relu"))
        if batch_norm:
            model.add(BatchNormalization())
        model.add(Dropout(0.5))

        # softmax classifier
        model.add(Dense(classes))
        model.add(Activation("softmax"))

        # return the constructed network architecture
        return model

# %%
# path to output model
model_path = "./models"

# %%
# load the training and testing data, then scale it into the range [0, 1]
print("[INFO] loading CIFAR-10 data...")
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype("float") / 255.0
testX = testX.astype("float") / 255.0
# Out:
# [INFO] loading CIFAR-10 data...

# %%
# convert the labels from integers to vectors
labelBinarizer = LabelBinarizer()
trainY = labelBinarizer.fit_transform(trainY)
testY = labelBinarizer.transform(testY)

# %%
# initialize the optimizer and model
print("[INFO] compiling model...")
opt = SGD(lr=0.01, decay=0.01 / 40, momentum=0.9, nesterov=True)
model = MiniVGGNet.build(width=32, height=32, depth=3, classes=10)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
# Out:
# [INFO] compiling model...

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
fname = os.path.sep.join([model_path, "minivgg-weights-{epoch:03d}-{val_loss:.4f}.hdf5"])
checkpoint = ModelCheckpoint(fname, monitor="val_loss", mode="min", save_best_only=True, verbose=1)
callbacks = [checkpoint]

# %%
# train the network
print("[INFO] training network...")
H = model.fit(trainX, trainY, 
              validation_data=(testX, testY), 
              batch_size=64, epochs=40, callbacks=callbacks, verbose=1)
# Out:
# [INFO] training network...
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 1.0070 - acc: 0.6484 - val_loss: 0.8303 - val_acc: 0.7075
#
# Epoch 00001: val_loss improved from 1.15101 to 0.83026, saving model to ./models/minivgg-weights-001-0.8303.hdf5
# Epoch 2/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.8809 - acc: 0.6914 - val_loss: 0.7889 - val_acc: 0.7224
#
# Epoch 00002: val_loss improved from 0.83026 to 0.78886, saving model to ./models/minivgg-weights-002-0.7889.hdf5
# Epoch 3/40
# 50000/50000 [==============================] - 11s 210us/step - loss: 0.8031 - acc: 0.7178 - val_loss: 0.8782 - val_acc: 0.6996
#
# Epoch 00003: val_loss did not improve from 0.78886
# Epoch 4/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.7398 - acc: 0.7398 - val_loss: 0.7217 - val_acc: 0.7500
#
# Epoch 00004: val_loss improved from 0.78886 to 0.72170, saving model to ./models/minivgg-weights-004-0.7217.hdf5
# Epoch 5/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.6964 - acc: 0.7538 - val_loss: 0.6851 - val_acc: 0.7563
#
# Epoch 00005: val_loss improved from 0.72170 to 0.68511, saving model to ./models/minivgg-weights-005-0.6851.hdf5
# Epoch 6/40
# 50000/50000 [==============================] - 11s 213us/step - loss: 0.6460 - acc: 0.7707 - val_loss: 0.6550 - val_acc: 0.7751
#
# Epoch 00006: val_loss improved from 0.68511 to 0.65499, saving model to ./models/minivgg-weights-006-0.6550.hdf5
# Epoch 7/40
# 50000/50000 [==============================] - 11s 212us/step - loss: 0.6163 - acc: 0.7832 - val_loss: 0.6669 - val_acc: 0.7701
#
# Epoch 00007: val_loss did not improve from 0.65499
# Epoch 8/40
# 50000/50000 [==============================] - 11s 210us/step - loss: 0.5855 - acc: 0.7937 - val_loss: 0.6150 - val_acc: 0.7883
#
# Epoch 00008: val_loss improved from 0.65499 to 0.61502, saving model to ./models/minivgg-weights-008-0.6150.hdf5
# Epoch 9/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.5574 - acc: 0.8029 - val_loss: 0.6005 - val_acc: 0.7942
#
# Epoch 00009: val_loss improved from 0.61502 to 0.60048, saving model to ./models/minivgg-weights-009-0.6005.hdf5
# Epoch 10/40
# 50000/50000 [==============================] - 11s 213us/step - loss: 0.5280 - acc: 0.8146 - val_loss: 0.5893 - val_acc: 0.7983
#
# Epoch 00010: val_loss improved from 0.60048 to 0.58926, saving model to ./models/minivgg-weights-010-0.5893.hdf5
# Epoch 11/40
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.5111 - acc: 0.8208 - val_loss: 0.5856 - val_acc: 0.7996
#
# Epoch 00011: val_loss improved from 0.58926 to 0.58563, saving model to ./models/minivgg-weights-011-0.5856.hdf5
# Epoch 12/40
# 50000/50000 [==============================] - 11s 214us/step - loss: 0.4929 - acc: 0.8237 - val_loss: 0.5790 - val_acc: 0.8050
#
# Epoch 00012: val_loss improved from 0.58563 to 0.57904, saving model to ./models/minivgg-weights-012-0.5790.hdf5
# Epoch 13/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.4714 - acc: 0.8326 - val_loss: 0.5701 - val_acc: 0.8042
#
# Epoch 00013: val_loss improved from 0.57904 to 0.57010, saving model to ./models/minivgg-weights-013-0.5701.hdf5
# Epoch 14/40
# 50000/50000 [==============================] - 11s 214us/step - loss: 0.4572 - acc: 0.8371 - val_loss: 0.5749 - val_acc: 0.8046
#
# Epoch 00014: val_loss did not improve from 0.57010
# Epoch 15/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.4462 - acc: 0.8417 - val_loss: 0.5791 - val_acc: 0.8045
#
# Epoch 00015: val_loss did not improve from 0.57010
# Epoch 16/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.4319 - acc: 0.8462 - val_loss: 0.5579 - val_acc: 0.8109
#
# Epoch 00016: val_loss improved from 0.57010 to 0.55794, saving model to ./models/minivgg-weights-016-0.5579.hdf5
# Epoch 17/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.4148 - acc: 0.8517 - val_loss: 0.5645 - val_acc: 0.8100
#
# Epoch 00017: val_loss did not improve from 0.55794
# Epoch 18/40
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.3979 - acc: 0.8577 - val_loss: 0.5585 - val_acc: 0.8135
#
# Epoch 00018: val_loss did not improve from 0.55794
# Epoch 19/40
# 50000/50000 [==============================] - 11s 214us/step - loss: 0.3902 - acc: 0.8608 - val_loss: 0.5556 - val_acc: 0.8145
#
# Epoch 00019: val_loss improved from 0.55794 to 0.55562, saving model to ./models/minivgg-weights-019-0.5556.hdf5
# Epoch 20/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.3763 - acc: 0.8654 - val_loss: 0.5557 - val_acc: 0.8140
#
# Epoch 00020: val_loss did not improve from 0.55562
# Epoch 21/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.3694 - acc: 0.8690 - val_loss: 0.5698 - val_acc: 0.8139
#
# Epoch 00021: val_loss did not improve from 0.55562
# Epoch 22/40
# 50000/50000 [==============================] - 11s 212us/step - loss: 0.3559 - acc: 0.8724 - val_loss: 0.5425 - val_acc: 0.8151
#
# Epoch 00022: val_loss improved from 0.55562 to 0.54248, saving model to ./models/minivgg-weights-022-0.5425.hdf5
# Epoch 23/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.3507 - acc: 0.8761 - val_loss: 0.5577 - val_acc: 0.8153
#
# Epoch 00023: val_loss did not improve from 0.54248
# Epoch 24/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.3396 - acc: 0.8787 - val_loss: 0.5486 - val_acc: 0.8197
#
# Epoch 00024: val_loss did not improve from 0.54248
# Epoch 25/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.3303 - acc: 0.8815 - val_loss: 0.5517 - val_acc: 0.8174
#
# Epoch 00025: val_loss did not improve from 0.54248
# Epoch 26/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.3229 - acc: 0.8842 - val_loss: 0.5473 - val_acc: 0.8203
#
# Epoch 00026: val_loss did not improve from 0.54248
# Epoch 27/40
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.3199 - acc: 0.8861 - val_loss: 0.5525 - val_acc: 0.8191
#
# Epoch 00027: val_loss did not improve from 0.54248
# Epoch 28/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.3112 - acc: 0.8893 - val_loss: 0.5488 - val_acc: 0.8208
#
# Epoch 00028: val_loss did not improve from 0.54248
# Epoch 29/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.3067 - acc: 0.8900 - val_loss: 0.5418 - val_acc: 0.8232
#
# Epoch 00029: val_loss improved from 0.54248 to 0.54179, saving model to ./models/minivgg-weights-029-0.5418.hdf5
# Epoch 30/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.2955 - acc: 0.8945 - val_loss: 0.5624 - val_acc: 0.8177
#
# Epoch 00030: val_loss did not improve from 0.54179
# Epoch 31/40
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.2867 - acc: 0.8958 - val_loss: 0.5522 - val_acc: 0.8211
#
# Epoch 00031: val_loss did not improve from 0.54179
# Epoch 32/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.2870 - acc: 0.8964 - val_loss: 0.5465 - val_acc: 0.8228
#
# Epoch 00032: val_loss did not improve from 0.54179
# Epoch 33/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.2783 - acc: 0.8994 - val_loss: 0.5485 - val_acc: 0.8239
#
# Epoch 00033: val_loss did not improve from 0.54179
# Epoch 34/40
# 50000/50000 [==============================] - 11s 222us/step - loss: 0.2732 - acc: 0.9013 - val_loss: 0.5490 - val_acc: 0.8222
#
# Epoch 00034: val_loss did not improve from 0.54179
# Epoch 35/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.2699 - acc: 0.9028 - val_loss: 0.5525 - val_acc: 0.8226
#
# Epoch 00035: val_loss did not improve from 0.54179
# Epoch 36/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.2615 - acc: 0.9077 - val_loss: 0.5566 - val_acc: 0.8212
#
# Epoch 00036: val_loss did not improve from 0.54179
# Epoch 37/40
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.2592 - acc: 0.9065 - val_loss: 0.5694 - val_acc: 0.8209
#
# Epoch 00037: val_loss did not improve from 0.54179
# Epoch 38/40
# 50000/50000 [==============================] - 11s 214us/step - loss: 0.2529 - acc: 0.9078 - val_loss: 0.5536 - val_acc: 0.8236
#
# Epoch 00038: val_loss did not improve from 0.54179
# Epoch 39/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.2472 - acc: 0.9113 - val_loss: 0.5536 - val_acc: 0.8257
#
# Epoch 00039: val_loss did not improve from 0.54179
# Epoch 40/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.2471 - acc: 0.9116 - val_loss: 0.5600 - val_acc: 0.8229
#
# Epoch 00040: val_loss did not improve from 0.54179

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
fname = os.path.sep.join([model_path, "minivgg-weights-best.hdf5"])
checkpoint = ModelCheckpoint(fname, monitor="val_loss", mode="min", save_best_only=True, verbose=1)
callbacks = [checkpoint]

# %%
H = model.fit(trainX, trainY, 
              validation_data=(testX, testY), 
              batch_size=64, epochs=40, callbacks=callbacks, verbose=1)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.2394 - acc: 0.9126 - val_loss: 0.5534 - val_acc: 0.8235
#
# Epoch 00001: val_loss improved from inf to 0.55336, saving model to ./models/minivgg-weights-best.hdf5
# Epoch 2/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.2382 - acc: 0.9141 - val_loss: 0.5533 - val_acc: 0.8250
#
# Epoch 00002: val_loss improved from 0.55336 to 0.55331, saving model to ./models/minivgg-weights-best.hdf5
# Epoch 3/40
# 50000/50000 [==============================] - 11s 212us/step - loss: 0.2361 - acc: 0.9154 - val_loss: 0.5633 - val_acc: 0.8241
#
# Epoch 00003: val_loss did not improve from 0.55331
# Epoch 4/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.2346 - acc: 0.9167 - val_loss: 0.5439 - val_acc: 0.8285
#
# Epoch 00004: val_loss improved from 0.55331 to 0.54386, saving model to ./models/minivgg-weights-best.hdf5
# Epoch 5/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.2286 - acc: 0.9178 - val_loss: 0.5547 - val_acc: 0.8250
#
# Epoch 00005: val_loss did not improve from 0.54386
# Epoch 6/40
# 50000/50000 [==============================] - 11s 214us/step - loss: 0.2238 - acc: 0.9198 - val_loss: 0.5532 - val_acc: 0.8263
#
# Epoch 00006: val_loss did not improve from 0.54386
# Epoch 7/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.2236 - acc: 0.9190 - val_loss: 0.5523 - val_acc: 0.8285
#
# Epoch 00007: val_loss did not improve from 0.54386
# Epoch 8/40
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.2206 - acc: 0.9206 - val_loss: 0.5782 - val_acc: 0.8191
#
# Epoch 00008: val_loss did not improve from 0.54386
# Epoch 9/40
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.2209 - acc: 0.9210 - val_loss: 0.5584 - val_acc: 0.8308
#
# Epoch 00009: val_loss did not improve from 0.54386
# Epoch 10/40
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.2118 - acc: 0.9245 - val_loss: 0.5501 - val_acc: 0.8280
#
# Epoch 00010: val_loss did not improve from 0.54386
# Epoch 11/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.2147 - acc: 0.9228 - val_loss: 0.5534 - val_acc: 0.8287
#
# Epoch 00011: val_loss did not improve from 0.54386
# Epoch 12/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.2078 - acc: 0.9258 - val_loss: 0.5626 - val_acc: 0.8273
#
# Epoch 00012: val_loss did not improve from 0.54386
# Epoch 13/40
# 50000/50000 [==============================] - 11s 214us/step - loss: 0.2085 - acc: 0.9247 - val_loss: 0.5507 - val_acc: 0.8279
#
# Epoch 00013: val_loss did not improve from 0.54386
# Epoch 14/40
# 50000/50000 [==============================] - 11s 213us/step - loss: 0.2017 - acc: 0.9266 - val_loss: 0.5646 - val_acc: 0.8263
#
# Epoch 00014: val_loss did not improve from 0.54386
# Epoch 15/40
# 50000/50000 [==============================] - 11s 214us/step - loss: 0.2029 - acc: 0.9280 - val_loss: 0.5616 - val_acc: 0.8274
#
# Epoch 00015: val_loss did not improve from 0.54386
# Epoch 16/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.1988 - acc: 0.9287 - val_loss: 0.5612 - val_acc: 0.8283
#
# Epoch 00016: val_loss did not improve from 0.54386
# Epoch 17/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.1929 - acc: 0.9314 - val_loss: 0.5580 - val_acc: 0.8296
#
# Epoch 00017: val_loss did not improve from 0.54386
# Epoch 18/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.1966 - acc: 0.9281 - val_loss: 0.5583 - val_acc: 0.8293
#
# Epoch 00018: val_loss did not improve from 0.54386
# Epoch 19/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.1945 - acc: 0.9306 - val_loss: 0.5639 - val_acc: 0.8304
#
# Epoch 00019: val_loss did not improve from 0.54386
# Epoch 20/40
# 50000/50000 [==============================] - 11s 213us/step - loss: 0.1854 - acc: 0.9335 - val_loss: 0.5717 - val_acc: 0.8302
#
# Epoch 00020: val_loss did not improve from 0.54386
# Epoch 21/40
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.1881 - acc: 0.9328 - val_loss: 0.5672 - val_acc: 0.8309
#
# Epoch 00021: val_loss did not improve from 0.54386
# Epoch 22/40
# 50000/50000 [==============================] - 11s 214us/step - loss: 0.1850 - acc: 0.9345 - val_loss: 0.5575 - val_acc: 0.8293
#
# Epoch 00022: val_loss did not improve from 0.54386
# Epoch 23/40
# 50000/50000 [==============================] - 11s 213us/step - loss: 0.1847 - acc: 0.9346 - val_loss: 0.5673 - val_acc: 0.8316
#
# Epoch 00023: val_loss did not improve from 0.54386
# Epoch 24/40
# 50000/50000 [==============================] - 11s 211us/step - loss: 0.1829 - acc: 0.9343 - val_loss: 0.5633 - val_acc: 0.8287
#
# Epoch 00024: val_loss did not improve from 0.54386
# Epoch 25/40
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.1784 - acc: 0.9367 - val_loss: 0.5588 - val_acc: 0.8302
#
# Epoch 00025: val_loss did not improve from 0.54386
# Epoch 26/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.1780 - acc: 0.9357 - val_loss: 0.5825 - val_acc: 0.8258
#
# Epoch 00026: val_loss did not improve from 0.54386
# Epoch 27/40
# 50000/50000 [==============================] - 11s 212us/step - loss: 0.1830 - acc: 0.9347 - val_loss: 0.5634 - val_acc: 0.8292
#
# Epoch 00027: val_loss did not improve from 0.54386
# Epoch 28/40
# 50000/50000 [==============================] - 11s 212us/step - loss: 0.1749 - acc: 0.9369 - val_loss: 0.5722 - val_acc: 0.8302
#
# Epoch 00028: val_loss did not improve from 0.54386
# Epoch 29/40
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.1769 - acc: 0.9373 - val_loss: 0.5645 - val_acc: 0.8304
#
# Epoch 00029: val_loss did not improve from 0.54386
# Epoch 30/40
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.1738 - acc: 0.9380 - val_loss: 0.5673 - val_acc: 0.8313
#
# Epoch 00030: val_loss did not improve from 0.54386
# Epoch 31/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.1696 - acc: 0.9394 - val_loss: 0.5732 - val_acc: 0.8312
#
# Epoch 00031: val_loss did not improve from 0.54386
# Epoch 32/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.1693 - acc: 0.9394 - val_loss: 0.5654 - val_acc: 0.8304
#
# Epoch 00032: val_loss did not improve from 0.54386
# Epoch 33/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.1665 - acc: 0.9411 - val_loss: 0.5678 - val_acc: 0.8314
#
# Epoch 00033: val_loss did not improve from 0.54386
# Epoch 34/40
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.1697 - acc: 0.9400 - val_loss: 0.5715 - val_acc: 0.8300
#
# Epoch 00034: val_loss did not improve from 0.54386
# Epoch 35/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.1675 - acc: 0.9401 - val_loss: 0.5600 - val_acc: 0.8302
#
# Epoch 00035: val_loss did not improve from 0.54386
# Epoch 36/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.1621 - acc: 0.9429 - val_loss: 0.5760 - val_acc: 0.8313
#
# Epoch 00036: val_loss did not improve from 0.54386
# Epoch 37/40
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.1595 - acc: 0.9420 - val_loss: 0.5709 - val_acc: 0.8294
#
# Epoch 00037: val_loss did not improve from 0.54386
# Epoch 38/40
# 50000/50000 [==============================] - 11s 215us/step - loss: 0.1636 - acc: 0.9419 - val_loss: 0.5744 - val_acc: 0.8291
#
# Epoch 00038: val_loss did not improve from 0.54386
# Epoch 39/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.1614 - acc: 0.9417 - val_loss: 0.5653 - val_acc: 0.8357
#
# Epoch 00039: val_loss did not improve from 0.54386
# Epoch 40/40
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.1609 - acc: 0.9420 - val_loss: 0.5618 - val_acc: 0.8318
#
# Epoch 00040: val_loss did not improve from 0.54386
